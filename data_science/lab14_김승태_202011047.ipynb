# %%
# Install required module (if not exists)
#!pip3 install pandas
#!pip3 install scikit-learn

# %%
# import packages
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans 
import pandas as pd
import random
from sklearn.datasets import make_blobs
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.metrics import rand_score
from sklearn.metrics import adjusted_rand_score
from sklearn.metrics import adjusted_mutual_info_score

# Set random seed for numpy and sklearn (scikit-learn)
np.random.seed(0)

# It will make your graph more fancy
plt.rcParams['font.family'] = 'Times New Roman'
plt.rcParams['font.size'] = 11.5

# %% [markdown]
# # **Datascience Lab 14**

# %%
def bmi_generator():
    while True:
        weight = random.randint(30, 140)
        height = random.randint(130, 200)
        bmi = weight / (height/100) ** 2
        if bmi<18.5:
            y = 0 # thin
        elif bmi>=25:
            y = 1 # fat
        else:
            continue # normal
        yield [weight, height], y
    
X = []
Y = []

bmi_gen = bmi_generator()

for i in range(3000):
    x, y = next(bmi_gen)
    X.append(x)
    Y.append(y)

X = np.array(X)
Y = np.array(Y)

bmi_map = {0: 'thin', 1: 'fat'}

plt.scatter(X[:,0], X[:,1],c= Y, s=30, edgecolors= 'black')
plt.show()
print('X shape is ', X.shape, 'Y shape is ', Y.shape)
# Out:
# X shape is  (3000, 2) Y shape is  (3000,)

# %% [markdown]
# ## Lab 14-1: kmeans (4 points)
# - Do kmeans clustering. Compare the graphs according to the number of clusters (3 vs 4). Set the `random_state` as 0
# - Paint in 'b', 'y', 'm', 'g' to the order on the label.
# - Set the center point size to 100 and color to red
# - Set the edgecolor to black
# - You have to subplot two graphs
#
# ### Hint
# - `cluster_centers`
# - `labels_`
# - `KMeans`
#
# ### Reference
# - https://scikit-learn.org/stable/modules/generated/sklearn.cluster.KMeans.html

# %%
### -------- LAB 14-1 START -------- ###

color = {0 : 'b', 1: 'y', 2: 'm'}

# do Kmeans
# fit model, for compared kmeans between n_clusters
kmeans = KMeans(n_clusters=2, random_state=0, n_init=10)
kmeans.fit(X)
kmeans2 = KMeans(n_clusters=3, random_state=0, n_init=10)
kmeans2.fit(X)

# set the colormap
A=kmeans.labels_
color1= [color[label] for label in A]
B=kmeans2.labels_
color2 =[color[label] for label in B]
# find the center of each cluster
center1 = kmeans.cluster_centers_
center2 = kmeans2.cluster_centers_


# Plot the graph 
fig, axs = plt.subplots(2,1, figsize=(12, 6))
axs[0].scatter(X[:, 0], X[:, 1], c=color1, s=30, edgecolors='black')
axs[0].scatter(center1[:, 0], center1[:, 1], c='red', s=100, edgecolors='black')
axs[0].set_title('Decision boundary - K-means clustering')

axs[1].scatter(X[:, 0], X[:, 1], c=color2, s=30, edgecolors='black')
axs[1].scatter(center2[:, 0], center2[:, 1], c='red', s=100, edgecolors='black')
### --------- LAB 14-1 END --------- ###

# %% [markdown]
# ### Evaluation code

# %%
print('The rand_score is',rand_score(Y, kmeans.predict(X)))
print('Adjusted rand score is', adjusted_rand_score(Y, kmeans.predict(X)))
print('Adjusted mutual information score is', adjusted_mutual_info_score(Y, kmeans.predict(X)))
# Out:
# The rand_score is 0.7089918861842837
# Adjusted rand score is 0.4120699955564309
# Adjusted mutual information score is 0.4293504774419825

# %%
print('The rand_score is',rand_score(Y, kmeans2.predict(X)))
print('Adjusted rand score is', adjusted_rand_score(Y, kmeans2.predict(X)))
print('Adjusted mutual information score is', adjusted_mutual_info_score(Y, kmeans2.predict(X)))
# Out:
# The rand_score is 0.7121660553517839
# Adjusted rand score is 0.46837015773306484
# Adjusted mutual information score is 0.6735779993716965

# %% [markdown]
# ## Q. Why does "k-means clustering" sometimes fail to work correctly for this dataset?

# %% [raw]
# K-means clustering은 범위를 너무 벗어난 값에 영향을 많이 받기 때문에, 이러한 값이 있으면, 잘못된 클러스터 할당을 일으킬 수 있고, 중심점에 큰 영향을 일으킬 수 있다.

# %% [markdown]
# ---
# ## Lab 14-2: Principal Component Analysis (6 points)
# - Using Iris dataset, Do dimensionality reduction with PCA. Choose the n_component to 2.
# - Before PCA, you have to pre-processing dataset (X - sepal length/width, petal length/width) with `StandardScaler()`.
# - Print the PCA variance ratio.
# - Plot the graph with two components
#
# ### Hint
# - `StandardScaler()`
# - `fit_transform`
# - `explained_variance_ratio_`
#
# ### Reference
# - https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.StandardScaler.html
# - https://scikit-learn.org/stable/modules/generated/sklearn.decomposition.PCA.html

# %%
### -------- LAB 14-2 START -------- ###
# Load iris dataset
iris = load_iris()
df = pd.DataFrame(data=iris.data, columns=iris.feature_names)
df.head(5)
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
# Preprocessing start (StandardScaler)
scaler = StandardScaler()
df_scaled = scaler.fit_transform(df)
display(pd.DataFrame(data = df_scaled,  columns=iris.feature_names).head(5))
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0          -0.900681          1.019004          -1.340227         -1.315444
# 1          -1.143017         -0.131979          -1.340227         -1.315444
# 2          -1.385353          0.328414          -1.397064         -1.315444
# 3          -1.506521          0.098217          -1.283389         -1.315444
# 4          -1.021849          1.249201          -1.340227         -1.315444

# %%
# PCA start
pcacomponents2 = PCA(n_components=2)
df_pca = pcacomponents2.fit_transform(df_scaled)
# plot graph
plt.scatter(df_pca[:, 0], df_pca[:, 1], c=iris.target, edgecolor='black')
plt.title('2 component PCA')
print("PCA variance ratio : ", pcacomponents2.explained_variance_ratio_)
### ----- Data science LAB END ----- ###
# Out:
# PCA variance ratio :  [0.72962445 0.22850762]
